# %%
from IPython.display import Audio
import numpy as np
import matplotlib.pyplot as plt
import scipy.io.wavfile
Audio('task.wav')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
fs, x = scipy.io.wavfile.read('task.wav')
print(fs)
print(x)
# Out:
# 44100
# [-29 -46 -46 ...   1   1  -3]

# %%
print(x.dtype)
# Out:
# int16

# %%
x.size
# Out:
# 143336

# %%
x1=x[8000:10000]                
k=np.arange(x1.size)            

plt.figure(figsize=[19, 4])       
plt.plot(k/fs, x1, 'b.')           
plt.grid()                             
plt.xlabel("$t$, c")                      
plt.ylabel("$x[k]$")             
plt.tight_layout()
